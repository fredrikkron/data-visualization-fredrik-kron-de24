# %% [markdown]
# # Exercise 1.0

# %%
import pandas as pd
import duckdb

df = pd.read_csv("data/1900-census-immigrant-pop-metro.csv")

df.head()
# Out:
#         City         State  Error Total foreign born  Africa  \
# 0      Akron          Ohio      0              7,127     4.0
# 1     Albany      New York     55             17,718     3.0
# 2  Allegheny  Pennsylvania      0             30,216     4.0
# 3  Allentown  Pennsylvania      3              2,991     NaN
# 4    Altoona  Pennsylvania     65              3,301     2.0
#
#    Asia (except China, Japan, and India) Atlantic Islands Australia Austria  \
# 0                                    NaN              NaN         1     190
# 1                                   39.0                4        13     106
# 2                                    5.0                2         8   3,929
# 3                                    1.0              NaN         2     337
# 4                                    7.0              NaN       NaN      57
#
#   Belgium  ... Scotland South America Spain  Sweden Switzerland Turkey Wales  \
# ...

# %%
columns = ["Sweden", "Norway", "Finland", "Denmark", "Total foreign born"]

df_nordic = df[columns]
df_nordic.head()
# Out:
#   Sweden Norway Finland Denmark Total foreign born
# 0    200     59       1     105              7,127
# 1     65     12       3      21             17,718
# 2    186      9       5      15             30,216
# 3      5      2     NaN       5              2,991
# 4     32      4       3       5              3,301

# %%
df_nordic = df_nordic.fillna("0")

# %%
for column in columns:
    df[column] = df_nordic[column].str.replace(",", "").astype(int)

df_nordic
# Out:
#     Sweden Norway Finland Denmark Total foreign born
# 0      200     59       1     105              7,127
# 1       65     12       3      21             17,718
# 2      186      9       5      15             30,216
# 3        5      2       0       5              2,991
# 4       32      4       3       5              3,301
# ..     ...    ...     ...     ...                ...
# 156     45      2      52       3             12,518
# 157  7,542    269   1,143     153             37,652
# 158    289     46       6      81             14,634
# 159     10      1       0       0              1,304
# 160    343     14      28      27             12,207
#
# [161 rows x 5 columns]

# %%
df_nordic = duckdb.query(
    """--sql
    WITH nordic AS (
        FROM df
            SELECT
                state,
                SUM("Total foreign born") AS "Total foreigners",
                SUM(sweden) AS Swedes,
                SUM(norway) AS Norweigans,
                SUM(denmark) AS Danish,
                SUM(finland) AS Finnish
            GROUP BY
                state
    )
    FROM nordic n
    SELECT *, n.swedes + n.norweigans + n.danish + n.finnish AS Nordic
    ORDER BY
        nordic
    DESC
""").df()

df_nordic
# Out:
#                    State  Total foreigners   Swedes  Norweigans   Danish  \
# 0               Illinois          627465.0  57158.0     22300.0  10374.0
# 1              Minnesota          128823.0  34984.0     17087.0   2975.0
# 2               New York         1521931.0  29961.0     11752.0   6186.0
# 3          Massachusetts          567170.0  21971.0      2366.0   1451.0
# 4              Wisconsin          124230.0   4034.0      6485.0   4024.0
# 5             California          160828.0   7223.0      2729.0   3082.0
# 6             Washington           40868.0   5150.0      3686.0   1193.0
# 7           Pennsylvania          514506.0   5986.0       861.0   1210.0
# 8               Nebraska           34456.0   4864.0       457.0   2888.0
# 9            Connecticut          101502.0   6647.0       273.0   1144.0
# 10                  Iowa           38173.0   4222.0      1519.0   1957.0
# 11            New Jersey          258498.0   2750.0      1483.0   1061.0
# ...

# %%
df_nordic.shape
# Out:
# (39, 7)

# %%
import matplotlib.pyplot as plt

top_3_nordic = df_nordic.drop(["Total foreigners", "Nordic"], axis=1).set_index("State").iloc[:3]

top_3_nordic
# Out:
#             Swedes  Norweigans   Danish  Finnish
# State
# Illinois   57158.0     22300.0  10374.0    447.0
# Minnesota  34984.0     17087.0   2975.0   1101.0
# New York   29961.0     11752.0   6186.0   3764.0

# %%
def nordic_plot():
    ax = top_3_nordic.plot(kind='bar', figsize=(12,6))
    ax.set_xticklabels(top_3_nordic.index, rotation = 0)

    fig = ax.get_figure()

    return fig, ax

nordic_plot()
# Out:
# (<Figure size 1200x600 with 1 Axes>, <Axes: xlabel='State'>)

# %%
fig, ax = nordic_plot()

ax.containers
# Out:
# [<BarContainer object of 3 artists>,
#  <BarContainer object of 3 artists>,
#  <BarContainer object of 3 artists>,
#  <BarContainer object of 3 artists>]

# %%
ax.containers[0]
# Out:
# <BarContainer object of 3 artists>

# %%
ax.containers[0][1].get_height(), ax.containers[0][1].get_x()
# Out:
# (np.float64(34984.0), np.float64(0.75))

# %% [markdown]
# ## Annotate

# %%
fig, ax = nordic_plot()

arrowprops = dict(arrowstyle = "->", linewidth=2, connectionstyle = "arc3, rad=.3")
ax.annotate(text = "Swedes", xy=(0.8, 35000), arrowprops=arrowprops, xytext=(0.8, 42000))
# Out:
# Text(0.8, 42000, 'Swedes')

# %%
from matplotlib.ticker import FuncFormatter

def format(x, pos):
    if x >= 1000:
        return f'{x*1.0/1000:.0f}K'
    else:
        return f'{x:.0f}'


fig, ax = nordic_plot()

swede_bars, norweigan_bars, danish_bars, finnish_bars = ax.containers

def annotate_nordic(bar_artist, text, x_offset, y_offset, fontsize=12, fontweight="bold"):
    bar_x = bar_artist.get_x()
    bar_y = bar_artist.get_height()
    xy = (bar_x + 0.06, bar_y)
    xytext = (bar_x + x_offset, bar_y + y_offset)
    fontsize=fontsize
    fontweight=fontweight

    # Determine curve direction based on where the label is
    rad = 0.3 if xytext[0] > xy[0] else -0.3

    arrowprops = dict(
        arrowstyle="->",
        linewidth=2,
        connectionstyle=f"arc3,rad={rad}"
    )

    ax.annotate(
        text=text,
        xy=xy,
        xytext=xytext,
        arrowprops=arrowprops,
        fontsize=fontsize,
        fontweight=fontweight
    )

annotate_nordic(swede_bars[0], "57158", 0.4, -1000)
annotate_nordic(swede_bars[1], "34984", 0.4, 3000)
annotate_nordic(swede_bars[2], "29961", 0.4, 3000)


ax.set_title(
    "The Swedish population immigrated more to USA than the rest of the Nordic countries together during the 20th century",
    loc="left",
    pad=10,
    fontweight="bold"
    )

legend = ax.legend(
    facecolor='lightgrey',
    edgecolor='black',
    framealpha=0.8,
    frameon=True
)
ax.set_facecolor("lightgrey")
fig.patch.set_facecolor("lightgrey")

ax.set_xlabel("State", fontweight="bold", loc="left")
ax.set_ylabel("Amount of people", fontweight="bold", loc="top")

ax.xaxis.set_label_coords(0.03, -0.05)
ax.spines[["top", "right"]].set_visible(False)
ax.yaxis.set_major_formatter(FuncFormatter(format))


fig = ax.get_figure()
fig.tight_layout()
fig.savefig("figures/finnish_immigration_to_United_States.png")
